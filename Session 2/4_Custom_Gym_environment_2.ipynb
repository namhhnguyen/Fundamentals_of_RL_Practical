# %% [markdown]
# **Goal**: Implement a custom Gymnasium environment and use Q-learning to solve it

# %% [markdown]
# ### Import

# %%
import os
import pickle

import gymnasium as gym
import numpy as np
from gymnasium.spaces import Box, Discrete
from matplotlib import pyplot as plt
from stable_baselines3 import PPO
from tqdm import tqdm

# %% [markdown]
# ### Subtract coin environment

# %% [markdown]
# **Task**: Based on 3_Custom_Gym_environment, implement a coin problem with coin values 51p, 5p, 3p.

# %% [markdown]
# ### Test - untrained model

# %% [markdown]
# **Task**: Test the untrained model

# %% [markdown]
# ### Solve problem with RL using Q-learning

# %% [markdown]
# **Task**: Solve the environment with Q-learning

# %% [markdown]
# ### Test - trained model - Q-learning

# %% [markdown]
# **Task**: Test the trained model
