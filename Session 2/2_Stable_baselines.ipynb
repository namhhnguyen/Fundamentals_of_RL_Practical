# %% [markdown]
# **Goal**: Use Stable Baselines 3 to solve Gymansium CartPole-v1

# %% [markdown]
# ### Import

# %%
import os

import gymnasium as gym
from stable_baselines3 import PPO
from tqdm import tqdm
import numpy as np

# %% [markdown]
# ### Stable Baselines 3

# %%
env_name = "CartPole-v1"

# %%
# Create tensorboard Logs and Saved models paths
log_path = os.path.join("Training", "Logs", env_name)
save_path = os.path.join("Training", "Saved Models", "PPO_Model_"+env_name )

# %%
# Create Cart Pole environement and train agent with PPO
env = gym.make(env_name)
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
model.learn(total_timesteps=60000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training/Logs/CartPole-v1/PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | 21.9     |
# | time/              |          |
# |    fps             | 7832     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | 27          |
# | time/                   |             |
# |    fps                  | 4639        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008577067 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.000308   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.56        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 50.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.2        |
# |    ep_rew_mean          | 35.2        |
# | time/                   |             |
# |    fps                  | 4193        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009904017 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.0887      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 37.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.8       |
# |    ep_rew_mean          | 45.8       |
# | time/                   |            |
# |    fps                  | 3990       |
# |    iterations           | 4          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00827877 |
# |    clip_fraction        | 0.0945     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.635     |
# |    explained_variance   | 0.255      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.4       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0202    |
# |    value_loss           | 53.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.3        |
# |    ep_rew_mean          | 62.3        |
# | time/                   |             |
# |    fps                  | 3861        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008606862 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 62.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.6        |
# |    ep_rew_mean          | 75.6        |
# | time/                   |             |
# |    fps                  | 3805        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006118433 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 61.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.9        |
# |    ep_rew_mean          | 94.9        |
# | time/                   |             |
# |    fps                  | 3735        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007103051 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00882    |
# |    value_loss           | 62.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 3699         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0061074416 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.6          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43           |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00744     |
# |    value_loss           | 56.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 126          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 3657         |
# |    iterations           | 9            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0065168785 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.46         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00852     |
# |    value_loss           | 34.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 3636         |
# |    iterations           | 10           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0040078564 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.9         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00725     |
# |    value_loss           | 49.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 163          |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 3605         |
# |    iterations           | 11           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0063672205 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.7         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 25.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 185         |
# | time/                   |             |
# |    fps                  | 3596        |
# |    iterations           | 12          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008200253 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 14.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 202          |
# | time/                   |              |
# |    fps                  | 3581         |
# |    iterations           | 13           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0040369234 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.48         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 34.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 220          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 3575         |
# |    iterations           | 14           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0053264117 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.532       |
# |    explained_variance   | 0.000131     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.289        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00352     |
# |    value_loss           | 26.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 237          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 3567         |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0051540206 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.758        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0124      |
# |    value_loss           | 4.37         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 253         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 3553        |
# |    iterations           | 16          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006586382 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | -0.00277    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0562      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 1.32        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 271        |
# |    ep_rew_mean          | 271        |
# | time/                   |            |
# |    fps                  | 3538       |
# |    iterations           | 17         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00272535 |
# |    clip_fraction        | 0.0191     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.528     |
# |    explained_variance   | 0.0398     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.273      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00211   |
# |    value_loss           | 18.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | 287          |
# | time/                   |              |
# |    fps                  | 3522         |
# |    iterations           | 18           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0046877624 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.534        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 2.41         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | 305          |
# | time/                   |              |
# |    fps                  | 3516         |
# |    iterations           | 19           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0052823476 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | 0.263        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0526       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00803     |
# |    value_loss           | 0.312        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 324         |
# |    ep_rew_mean          | 324         |
# | time/                   |             |
# |    fps                  | 3513        |
# |    iterations           | 20          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006588023 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | -0.0422     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0033     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 0.192       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 339         |
# | time/                   |             |
# |    fps                  | 3512        |
# |    iterations           | 21          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003213363 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.46       |
# |    explained_variance   | 0.0801      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0154      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00112    |
# |    value_loss           | 0.134       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 352          |
# | time/                   |              |
# |    fps                  | 3510         |
# |    iterations           | 22           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0013460673 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.457       |
# |    explained_variance   | 0.0894       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.015        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 7.19e-05     |
# |    value_loss           | 0.0745       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 367          |
# |    ep_rew_mean          | 367          |
# | time/                   |              |
# |    fps                  | 3509         |
# |    iterations           | 23           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0020446596 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | 0.00386      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000767    |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000129    |
# |    value_loss           | 0.0505       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 381         |
# |    ep_rew_mean          | 381         |
# | time/                   |             |
# |    fps                  | 3507        |
# |    iterations           | 24          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003612592 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | -0.00598    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00143     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000881   |
# |    value_loss           | 0.0297      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 393          |
# |    ep_rew_mean          | 393          |
# | time/                   |              |
# |    fps                  | 3508         |
# |    iterations           | 25           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0029032277 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | -0.00432     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00947      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 0.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 409          |
# |    ep_rew_mean          | 409          |
# | time/                   |              |
# |    fps                  | 3508         |
# |    iterations           | 26           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0055939946 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | 0.0529       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00645     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 0.013        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 421         |
# |    ep_rew_mean          | 421         |
# | time/                   |             |
# |    fps                  | 3507        |
# |    iterations           | 27          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004371499 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | -0.00392    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0193      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00204    |
# |    value_loss           | 0.00853     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 433         |
# |    ep_rew_mean          | 433         |
# | time/                   |             |
# |    fps                  | 3502        |
# |    iterations           | 28          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.001809167 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.464      |
# |    explained_variance   | -0.0251     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000606    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000905   |
# |    value_loss           | 0.00554     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 441         |
# |    ep_rew_mean          | 441         |
# | time/                   |             |
# |    fps                  | 3501        |
# |    iterations           | 29          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006738249 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.444      |
# |    explained_variance   | -0.00387    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00922     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 0.00372     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 453          |
# |    ep_rew_mean          | 453          |
# | time/                   |              |
# |    fps                  | 3501         |
# |    iterations           | 30           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0027069903 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | 0.00862      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000261     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000667    |
# |    value_loss           | 0.00241      |
# ------------------------------------------

# %%
# Save trained model
model.save(save_path)

# %% [markdown]
# ### Test - trained policy

# %%
# Test model
env = gym.make(env_name)
model = PPO.load(save_path, env=env)

total_rewards = []
episodes = 1000
for episode in tqdm(range(episodes)):
    state, _ = env.reset()
    score = 0

    while True:
        # Perform the chosen action and observe the next state and reward
        action, _  = model.predict(state, deterministic=True)
        state, reward, terminated, truncated, info = env.step(action)
        score += reward
        if terminated or truncated:
            total_rewards.append(score)
            break
total_rewards = np.array(total_rewards)
env.close()

print(
    f"The mean reward is {np.mean(total_rewards)} and the standard deviation is {np.std(total_rewards)}."
)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 100%|██████████| 1000/1000 [00:38<00:00, 25.64it/s]
# The mean reward is 500.0 and the standard deviation is 0.0.
